# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jIg8AWoQWnO1fRFTFgjU")
project = rf.workspace("fyp-coz6v").project("bovine-body-disease-detection")
version = project.version(3)
dataset = version.download("tensorflow")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\PC0\Documents\bovine disease__pfe benzaouche_harbane\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Bovine-Body-Disease-Detection-3 in tensorflow:: 100%|██████████| 27180/27180 [00:09<00:00, 2991.65it/s]

# %%
path = r"C:\Users\PC0\Documents\bovine disease__pfe benzaouche_harbane\Bovine-Body-Disease-Detection-3"

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
#This tells PIL:
#"If image is slightly broken, load what you can."

# %%
import os
from pathlib import Path

dataset_path = Path(path)  # path returned by kagglehub
print("Dataset root:", dataset_path)
print("\nDirectory structure:")
for root, dirs, files in os.walk(dataset_path):
    level = root.replace(str(dataset_path), '').count(os.sep)
    indent = ' ' * 2 * level
    print(f"{indent}{os.path.basename(root)}/ ({len(files)} files)")
# Out:
# Dataset root: C:\Users\PC0\Documents\bovine disease__pfe benzaouche_harbane\Bovine-Body-Disease-Detection-3
#
# Directory structure:
# Bovine-Body-Disease-Detection-3/ (2 files)
#   test/ (643 files)
#   train/ (25886 files)
#   valid/ (646 files)

# %%
import pandas as pd
df = pd.read_csv(r"Bovine-Body-Disease-Detection-3\train\_annotations.csv")
df["class"].value_counts()
# Out:
# class
# Healthy Skin    17890
# Ringworm         8605
# LSD              7835
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

class_counts = df["class"].value_counts()

labels = class_counts.index
values = class_counts.values

plt.bar(labels, values)
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Number of Images")
plt.xticks(rotation=45)
plt.show()
